# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import plotly.graph_objects as go

import torch

from tqdm import tqdm

# %% [markdown]
# # Multiclass Trade Classifier (TCN) — Training Template
#
# Trains a 3-class sequence classifier to identify high-probability trade entries:
# **SELL (class 0)**, **FLAT (class 1)**, or **BUY (class 2)** — using causal triple-barrier labeling.
#
# **To use this notebook as a template:**
# 1. Set all experiment parameters in the **Configuration** cell below
# 2. Adjust label params, model architecture, and loss weights as needed
# 3. Run all cells sequentially — the trained model pack is saved to `Engine/Model Packs/`
#
# | Component | Description |
# |---|---|
# | Labels | Causal triple-barrier with Hi/Lo trend filter → SELL=0 / FLAT=1 / BUY=2 |
# | Features | OHLCV + ATR + regime indicators (parity with live engine) |
# | Model | `TCNAttentionSEClassifier` with `num_classes=3` |
# | Loss | `TradeProfitabilityLoss` — focal CE + soft expected-profit optimisation |

# %%
from Learn.features import _add_features_US500

# ── DATASET & TASK ────────────────────────────────────────────────────────────
DS_NAME   = '../data/US500_1minute.csv'  # Path to OHLCV CSV
TEST_START = '2026-01-01'               # Date to split train / validation
N_ROWS    = None                   # Max rows to load (None = all)
FEATURES = _add_features_US500

# ── SEQUENCE & BATCH ──────────────────────────────────────────────────────────
SEQ_LEN    = 256    # 512 × 1-min ≈ 8 hours lookback window
BATCH_SIZE = 256          # was 512

# ── OPTIMISER ─────────────────────────────────────────────────────────────────
NUM_EPOCHS   = 25           # was 10 — more time to climb past initial FLAT bias
BASE_LR      = 1.5e-4       # was 8e-5 — faster initial gradient signal
WEIGHT_DECAY = 3e-4         # was 8e-4 — less L2 to reduce underfitting

# ── PREPROCESSING ─────────────────────────────────────────────────────────────
HOLDOUT_SIZE    = 0.10                # Fraction of training data used as internal holdout
ROLLOVER_WINDOW = ('21:30', '22:00')  # Broker rollover window: targets zeroed out
TRADING_HOURS   = None                # Set e.g. ('07:00', '20:00') to gate by session

# ── FEES & COMMISSIONS ────────────────────────────────────────────────────────
COMMISSION = 0.10   # Fraction of trade outcome deducted as broker fee

# ── EXPORT ────────────────────────────────────────────────────────────────────
MODEL_VERSION = 'dev'  # Version tag appended to saved model pack filename

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# ## Load Dataset

# %%
def load_ohlcv(ds_name, n_rows=None):
    df = pd.read_csv(ds_name)
    if n_rows is not None:
        df = df.tail(n_rows)
    df = df.sort_values('Time').reset_index(drop=True)
    return df

def train_val_split(df, test_date=None):
    if test_date is None:
        return df, None
    test_start = df[df['Time'] > test_date].index[0]
    df_test  = df.iloc[test_start:, :].copy().reset_index(drop=True)
    df_train = df[df['Time'] < test_date].reset_index(drop=True)
    return df_train, df_test

df = load_ohlcv(DS_NAME, N_ROWS)
df, df_test = train_val_split(df, TEST_START)
print(f"Train: {len(df):,} rows | Val: {len(df_test):,} rows")
# Out:
# Train: 3,153,645 rows | Val: 52,051 rows

# %% [markdown]
# ## Label Configuration
#
# Tune the triple-barrier parameters to control entry selectivity.
# Higher `tp_mult`/`sl_mult` ratio → fewer but better-quality entries.
# Increase `trend_pullback_thresh` to require stronger trend confirmation.

# %%
from Learn.labels import causal_triple_barrier_hilow_trend_labeler, calculate_trade_outcomes_all_candles

# ── Regime detection ─────────────────────────────────────────────────────────
regime_params = {
      "ma_period": 50,
      "slope_smoothness": 30,
      "regime_min_duration": 0,
      "atr_window": 60,
      "atr_lookback": 1440,
      "atr_percentile": 0.0,
      "slope_threshold": 0.03
    }

# ── Triple-barrier labelling ──────────────────────────────────────────────────
label_params = {
      "z_window": 14,
      "z_thresh": 1,
      "z_limit": 5,
      "atr_window": 14,
      "tp_mult": 2.5,
      "sl_mult": 2.5,
      "max_horizon": 90,
      "trend_pullback_thresh": 1.0,
      "regime_params": regime_params,
      "skip_range": True
    }

# %% [markdown]
# ## Generate Trade Entry Labels
#
# Uses `causal_triple_barrier_hilow_trend_labeler` with fully causal parameters.
# Winning bars where a trade succeeds are mapped to:
# - **SELL (0)** — for `target == -1` wins
# - **BUY  (2)** — for `target == +1` wins
# - **FLAT (1)** — all other bars, plus the broker rollover window

# %%
for name, d in [('df', df), ('df_test', df_test)]:
    signals = causal_triple_barrier_hilow_trend_labeler(d, **label_params).rename(columns={'side': 'target'})
    winning  = signals[signals['label'] == 1]

    # Multiclass targets: 0 = SELL, 1 = FLAT, 2 = BUY
    d['target'] = 1  # default: FLAT
    d.loc[winning[winning['target'] ==  1].index, 'target'] = 2  # BUY
    d.loc[winning[winning['target'] == -1].index, 'target'] = 0  # SELL

    # Zero-out targets during rollover window
    if not pd.api.types.is_datetime64_any_dtype(d['Time']):
        d['Time'] = pd.to_datetime(d['Time'])
    rollover = (
        (d['Time'].dt.time >= pd.to_datetime(ROLLOVER_WINDOW[0]).time()) &
        (d['Time'].dt.time <  pd.to_datetime(ROLLOVER_WINDOW[1]).time())
    )
    d.loc[rollover, 'target'] = 1  # force FLAT during rollover
    print(f"{name}: {rollover.sum()} rollover rows zeroed | target dist:")
    print(d['target'].value_counts().sort_index().rename({0:'SELL',1:'FLAT',2:'BUY'}), "\n")

df_val = df_test.copy()
# Out:
# df: 26934 rollover rows zeroed | target dist:
# target
# SELL      66105
# FLAT    3014394
# BUY       73146
# Name: count, dtype: int64
#
# df_test: 978 rollover rows zeroed | target dist:
# target
# SELL     1264
# FLAT    49249
# BUY      1538
# Name: count, dtype: int64

# %% [markdown]
# ## Calculate Trade Outcomes
#
# Computes per-bar TP/SL/timeout outcomes for every candle (both BUY and SELL directions).
# Both outcome columns are stored in `sell_y` / `buy_y` — column names already excluded from
# the feature matrix by `preprocess_ohlcv`.  Winning outcomes are doubled to increase the
# reward signal for correct predictions.

# %%
outcome_params = {k: v for k, v in label_params.items()
                  if k in ['atr_window', 'tp_mult', 'sl_mult', 'max_horizon']}
outcome_params['max_horizon'] = 1000

for name, d in [('df', df), ('df_val', df_val)]:
    outcomes = calculate_trade_outcomes_all_candles(d, **outcome_params)

    # Double TP rewards to strengthen the profit signal
    for col in ['buy_outcome', 'sell_outcome']:
        outcomes[col] = outcomes[col].clip(upper=None).where(outcomes[col] <= 0, outcomes[col] * 2)

    # Store in columns that preprocess_ohlcv already excludes from features
    d['sell_y'] = outcomes['sell_outcome'].fillna(0.0)
    d['buy_y']  = outcomes['buy_outcome'].fillna(0.0)

    tp  = (outcomes['buy_outcome']  == 2).sum()
    sl  = (outcomes['buy_outcome']  == -1).sum()
    to  = (outcomes['buy_outcome']  == 0).sum()
    stp = (outcomes['sell_outcome'] == 2).sum()
    ssl = (outcomes['sell_outcome'] == -1).sum()
    sto = (outcomes['sell_outcome'] == 0).sum()
    print(f"{name} outcomes | Buy  TP:{tp} TO:{to} SL:{sl} | Sell TP:{stp} TO:{sto} SL:{ssl}")

print('\nTrain label dist (%):\n',
      df['target'].value_counts(normalize=True).sort_index()
        .rename({0:'SELL', 1:'FLAT', 2:'BUY'}).mul(100).round(1))
# Out:
# df outcomes | Buy  TP:1339222 TO:0 SL:1814380 | Sell TP:1283644 TO:1 SL:1869962
# df_val outcomes | Buy  TP:20874 TO:0 SL:31154 | Sell TP:21470 TO:0 SL:30558
#
# Train label dist (%):
#  target
# SELL     2.1
# FLAT    95.6
# BUY      2.3
# Name: proportion, dtype: float64

# %% [markdown]
# ## Feature Engineering
#
# Adds technical indicators to the OHLCV data.
# Features are computed in-parity with the live trading engine.

# %%
df     = FEATURES(df, regime_params=regime_params)
df_val = FEATURES(df_val, regime_params=regime_params)
# Out:
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1047: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_trix_14'] = talib.TRIX(close, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1053: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dpo_20'] = (close - _ema_dpo.shift(_dpo_shift)) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1056: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cci_14'] = talib.CCI(high, low, close, timeperiod=14) / 200.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1057: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cci_20'] = talib.CCI(high, low, close, timeperiod=20) / 200.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1060: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_willr_14'] = talib.WILLR(high, low, close, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1064: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_aroon_osc_14'] = (aroon_u - aroon_d) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1068: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_norm']     = macd_hist / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1069: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_line_norm']     = macd_line / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1070: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_slope_5']  = macd_hist.diff(5) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1073: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_mfi_14'] = talib.MFI(high, low, close, vol, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1087: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_tk_diff']       = (tenkan - kijun) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1088: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_close_vs_kijun']= (close  - kijun) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1089: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_senA_vs_senB']  = (senA   - senB)  / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1090: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_close_vs_cloud']= (close  - ((senA + senB) / 2.0)) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1091: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_chikou_vs_close']= (chikou - close) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1095: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_bull_power'] = (high - ema13) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1096: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_bear_power'] = (low  - ema13) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1102: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_kelt_pos']   = (close - kelt_mid)   / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_kelt_width'] = (kelt_upper - kelt_lower) / (close + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_squeeze'] = ((bb_l > kelt_lower) & (bb_u < kelt_upper)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_squeeze_mom'] = _sq_mom / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_log_volume']   = np.log1p(vol)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_volume_z']     = (vol - _vmean) / (_vstd + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vol_direction']= np.sign(log_ret.fillna(0)) * df['fl_volume_z']
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_obv_slope_10'] = pd.Series(_obv).diff(10) / (vol.rolling(10).mean() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cmf_20'] = _mf_vol.rolling(20).sum() / (vol.rolling(20).sum() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_force_index_13'] = talib.EMA(pd.Series(_fi), timeperiod=13) / (vol.rolling(13).mean() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1141: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_nvi_z'] = (_nvi - _nvi_ma) / (_nvi.rolling(60).std() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vwap64_diff']  = (close - vwap64)  / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1147: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vwap256_diff'] = (close - vwap256) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1160: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_run_len'] = _run
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_pp_pos']    = (close - _pp) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1170: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_r1_dist']   = (close - _r1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_s1_dist']   = (close - _s1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1186: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_fractal_high'] = _frac_hi
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1187: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_fractal_low']  = _frac_lo
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1191: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_round_num_dist'] = (close - _round_level).abs() / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1195: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'fl_ret_lag_{_lag}'] = log_ret.shift(_lag)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1196: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_rsi14_lag_1']       = talib.RSI(close, timeperiod=14).shift(1) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1197: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_rsi14_lag_2']       = talib.RSI(close, timeperiod=14).shift(2) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_lag_1']   = macd_hist.shift(1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_stoch_k_lag_1']     = sk.shift(1) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1204: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_hour_sin']  = np.sin(2 * np.pi * _h  / 24.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1205: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_hour_cos']  = np.cos(2 * np.pi * _h  / 24.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1206: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dow_sin']   = np.sin(2 * np.pi * _dw / 5.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1207: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dow_cos']   = np.cos(2 * np.pi * _dw / 5.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1210: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_tokyo']  = ((_h >= 0)  & (_h < 9)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1211: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_london'] = ((_h >= 7)  & (_h < 16)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1212: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_ny']     = ((_h >= 12) & (_h < 21)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_overlap']= ((_h >= 12) & (_h < 16)).astype(int)  # London/NY overlap
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1231: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[_name] = _fn(open_, high, low, close) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1234: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_inside_bar']  = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_outside_bar'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1240: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_expand'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1243: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_contract'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_vs_atr5'] = df['fl_hl_range'].rolling(5).mean() / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_regime'] = causal_market_regime(df, **regime_params)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1047: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_trix_14'] = talib.TRIX(close, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1053: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dpo_20'] = (close - _ema_dpo.shift(_dpo_shift)) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1056: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cci_14'] = talib.CCI(high, low, close, timeperiod=14) / 200.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1057: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cci_20'] = talib.CCI(high, low, close, timeperiod=20) / 200.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1060: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_willr_14'] = talib.WILLR(high, low, close, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1064: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_aroon_osc_14'] = (aroon_u - aroon_d) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1068: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_norm']     = macd_hist / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1069: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_line_norm']     = macd_line / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1070: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_slope_5']  = macd_hist.diff(5) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1073: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_mfi_14'] = talib.MFI(high, low, close, vol, timeperiod=14) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1087: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_tk_diff']       = (tenkan - kijun) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1088: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_close_vs_kijun']= (close  - kijun) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1089: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_senA_vs_senB']  = (senA   - senB)  / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1090: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_close_vs_cloud']= (close  - ((senA + senB) / 2.0)) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1091: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_ichi_chikou_vs_close']= (chikou - close) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1095: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_bull_power'] = (high - ema13) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1096: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_bear_power'] = (low  - ema13) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1102: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_kelt_pos']   = (close - kelt_mid)   / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_kelt_width'] = (kelt_upper - kelt_lower) / (close + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_squeeze'] = ((bb_l > kelt_lower) & (bb_u < kelt_upper)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_squeeze_mom'] = _sq_mom / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_log_volume']   = np.log1p(vol)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_volume_z']     = (vol - _vmean) / (_vstd + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vol_direction']= np.sign(log_ret.fillna(0)) * df['fl_volume_z']
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_obv_slope_10'] = pd.Series(_obv).diff(10) / (vol.rolling(10).mean() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_cmf_20'] = _mf_vol.rolling(20).sum() / (vol.rolling(20).sum() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_force_index_13'] = talib.EMA(pd.Series(_fi), timeperiod=13) / (vol.rolling(13).mean() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1141: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_nvi_z'] = (_nvi - _nvi_ma) / (_nvi.rolling(60).std() + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vwap64_diff']  = (close - vwap64)  / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1147: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_vwap256_diff'] = (close - vwap256) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1160: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_run_len'] = _run
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1169: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_pp_pos']    = (close - _pp) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1170: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_r1_dist']   = (close - _r1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_s1_dist']   = (close - _s1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1186: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_fractal_high'] = _frac_hi
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1187: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_fractal_low']  = _frac_lo
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1191: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_round_num_dist'] = (close - _round_level).abs() / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1195: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'fl_ret_lag_{_lag}'] = log_ret.shift(_lag)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1196: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_rsi14_lag_1']       = talib.RSI(close, timeperiod=14).shift(1) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1197: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_rsi14_lag_2']       = talib.RSI(close, timeperiod=14).shift(2) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1198: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_macd_hist_lag_1']   = macd_hist.shift(1) / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1199: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_stoch_k_lag_1']     = sk.shift(1) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1204: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_hour_sin']  = np.sin(2 * np.pi * _h  / 24.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1205: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_hour_cos']  = np.cos(2 * np.pi * _h  / 24.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1206: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dow_sin']   = np.sin(2 * np.pi * _dw / 5.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1207: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_dow_cos']   = np.cos(2 * np.pi * _dw / 5.0)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1210: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_tokyo']  = ((_h >= 0)  & (_h < 9)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1211: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_london'] = ((_h >= 7)  & (_h < 16)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1212: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_ny']     = ((_h >= 12) & (_h < 21)).astype(int)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_session_overlap']= ((_h >= 12) & (_h < 16)).astype(int)  # London/NY overlap
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1231: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[_name] = _fn(open_, high, low, close) / 100.0
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1234: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_inside_bar']  = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1237: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_outside_bar'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1240: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_expand'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1243: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_contract'] = (
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1247: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_range_vs_atr5'] = df['fl_hl_range'].rolling(5).mean() / (atr14 + eps)
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\ModelWorkbench\Learn\features.py:1255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['fl_regime'] = causal_market_regime(df, **regime_params)

# %% [markdown]
# ## Preprocessing & Scaling
#
# The scaler is **fit on the training split only** and then applied to the validation split.
#
# The `sell_y` / `buy_y` columns carry trade outcomes through the preprocessing pipeline
# (they are excluded from the feature matrix by `preprocess_ohlcv`) and are then stacked
# into a `(N, 2)` array — `[:, 0]` = sell outcome, `[:, 1]` = buy outcome — passed directly
# to `TradeProfitabilityLoss` during training.

# %%
from Learn.preprocess import preprocess_ohlcv

preprocess_ohlcv_args = {
    'target_col':      'target',
    'outcomes_col':    None,   # outcomes extracted from proc_df via sell_y / buy_y
    'shift':           0,
    'onehot_prefixes': ['OH_'],
    'price_prefixes':  ['PR_'],
}

split_idx = int(len(df) * (1 - HOLDOUT_SIZE))

X_train, y_train, scaler, features, _, proc_df_train = preprocess_ohlcv(
    df.iloc[:split_idx].copy(), **preprocess_ohlcv_args, scaler=None, return_df=True)

X_test, y_test, _, _, _, proc_df_test = preprocess_ohlcv(
    df.iloc[split_idx:].copy(), **preprocess_ohlcv_args, scaler=scaler, return_df=True)

X_train = np.ascontiguousarray(X_train)
X_test  = np.ascontiguousarray(X_test)

y_train = [int(x) for x in y_train]
y_test  = [int(x) for x in y_test]

# Extract NaN-aligned outcomes from proc_df (sell_y / buy_y survive dropna since they were fillna'd)
outcomes_train_2d = np.stack([proc_df_train['sell_y'].values,
                               proc_df_train['buy_y'].values], axis=1).astype(float)
outcomes_test_2d  = np.stack([proc_df_test['sell_y'].values,
                               proc_df_test['buy_y'].values], axis=1).astype(float)

train_idx = list(range(len(X_train)))
test_idx  = list(range(len(X_test)))

# Anchor-time session gating
def _session_seq_indices(times, seq_len, trading_hours):
    if trading_hours is None:
        return list(range(len(times) - seq_len))
    t_start = pd.to_datetime(trading_hours[0]).time()
    t_end   = pd.to_datetime(trading_hours[1]).time()
    return [
        i for i in range(len(times) - seq_len)
        if t_start <= pd.Timestamp(times[i + seq_len - 1]).time() < t_end
    ]

train_times = proc_df_train['Time'].to_numpy()
test_times  = proc_df_test['Time'].to_numpy()

train_seq_idx = _session_seq_indices(train_times, SEQ_LEN, TRADING_HOURS)
test_seq_idx  = _session_seq_indices(test_times,  SEQ_LEN, TRADING_HOURS)

n_train_all = len(X_train) - SEQ_LEN
n_test_all  = len(X_test)  - SEQ_LEN
print(f"Train: {X_train.shape} | Test: {X_test.shape}")
print(f"Session-gated seqs -- Train: {len(train_seq_idx):,}/{n_train_all:,} "
      f"| Test: {len(test_seq_idx):,}/{n_test_all:,}  (TRADING_HOURS={TRADING_HOURS})")
# Out:
# Warning: Neither legacy nor new base features found. No features will be scaled.
# Warning: Neither legacy nor new base features found. No features will be scaled.
# Train: (2838025, 89) | Test: (315365, 89)
# Session-gated seqs -- Train: 2,837,769/2,837,769 | Test: 315,109/315,109  (TRADING_HOURS=None)

# %% [markdown]
# ## Data Loaders
#
# Each sample includes a `(2,)` outcome tensor `[sell_outcome, buy_outcome]` which is
# passed directly to `TradeProfitabilityLoss` to optimise for expected profit.

# %%
from Learn.Loaders import SequenceDataset
from torch.utils.data import DataLoader

train_ds = SequenceDataset(X_train, y_train, seq_len=SEQ_LEN, df_idx=train_idx,
                           custom_targets=None, trade_outcomes=outcomes_train_2d,
                           seq_idx_filter=train_seq_idx)
val_ds   = SequenceDataset(X_test,  y_test,  seq_len=SEQ_LEN, df_idx=test_idx,
                           custom_targets=None, trade_outcomes=outcomes_test_2d,
                           seq_idx_filter=test_seq_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          pin_memory=True, num_workers=0)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          pin_memory=True, num_workers=0)

print(f"DataLoaders ready -- train batches: {len(train_loader):,} | val batches: {len(val_loader):,}")
# Out:
# DataLoaders ready -- train batches: 11,086 | val batches: 1,231

# %% [markdown]
# ## Model
#
# `TCNAttentionSEClassifier` with `num_classes=3` — same architecture as the binary TCN model
# but with a 3-head output (SELL / FLAT / BUY).
#
# The TCN receptive field should roughly match `SEQ_LEN`:
# `(kernel_size - 1) × (2^num_layers - 1) × 2 + 1 ≈ SEQ_LEN`
#
# With `kernel_size=3` and `num_layers=6`: RF ≈ (3-1) × (64-1) × 2 + 1 = 253 bars ✓
#
# The log-prior bias initialisation uses all three class frequencies to prevent
# the model spending early epochs learning the class imbalance from scratch.
#
# | Param | Description |
# |---|---|
# | `hidden_channels` | Number of feature maps in each TCN block |
# | `num_layers` | Number of TCN blocks (controls receptive field via 2^i dilation) |
# | `kernel_size` | Conv kernel size — increase for smoother temporal features |
# | `attn_heads` | Heads for MHA pooling — must divide `hidden_channels` evenly |
# | `bias_init` | 3-element log-prior bias `[log(p_sell), log(p_flat), log(p_buy)]` |

# %%
from Learn.Models import TCNAttentionSEClassifier

# 3-class log-prior bias, with a small trade penalty to keep early epochs conservative.
y_train_arr = np.array(y_train)
p_sell = (y_train_arr == 0).mean()
p_flat = (y_train_arr == 1).mean()
p_buy  = (y_train_arr == 2).mean()
trade_bias_offset = 0.15   # was 0.35 — heavy offset compounded the class collapse
bias_init = [
    math.log(p_sell + 1e-8) - trade_bias_offset,
    math.log(p_flat + 1e-8),
    math.log(p_buy + 1e-8) - trade_bias_offset,
]
print(f"Class rates -- SELL: {p_sell:.4f}  FLAT: {p_flat:.4f}  BUY: {p_buy:.4f}")
print(f"trade_bias_offset: {trade_bias_offset:.2f}")
print(f"bias_init: {[round(b, 3) for b in bias_init]}")

# Fixes applied:
# - dropout_out 0.60 → 0.30: was killing signal before the head (primary underfitting cause)
# - dropout 0.30 → 0.25: minor reduction to reduce overall regularization pressure
# - attn_dropout 0.20 → 0.15: reduce attention masking
model_params = {
    'input_dim':         X_train.shape[1],
    'hidden_channels':   128,
    'num_layers':        6,
    'kernel_size':       3,
    'num_classes':       3,
    'dropout':           0.25,    # was 0.30
    'dropout_out':       0.30,    # was 0.60 — the main underfitting driver
    'attn_heads':        4,
    'attn_dropout':      0.15,    # was 0.20
    'use_learned_query': True,
    'bias_init':         bias_init,
}

model = TCNAttentionSEClassifier(**model_params).to(device)
MODEL_TYPE = 'TCN_Multiclass'
print(f"Model: {MODEL_TYPE} | Params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Class rates -- SELL: 0.0204  FLAT: 0.9568  BUY: 0.0228
# trade_bias_offset: 0.15
# bias_init: [-4.043, -0.044, -3.932]
# Model: TCN_Multiclass | Params: 668,563
# c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\torch\nn\utils\weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %% [markdown]
# ### Class Weights & Loss Function
#
# `TradeProfitabilityLoss` combines:
# - Focal cross-entropy (handles class imbalance)
# - Soft precision/recall optimisation for trade classes {0, 2}
# - Soft expected-profit term: `sum(p_sell * sell_outcome + p_buy * buy_outcome)` per batch
#
# This gives the optimiser a direct, fully-differentiable profit signal on every training step.

# %%
from Learn.Loss import TradeProfitabilityLoss

# FLAT weight reduced 4.0 → 3.5: combined with the old loss params, 4.0 made predicting
# FLAT the dominant gradient direction. 3.5 still makes false trades costly but allows recovery.
weights = np.array([1.0, 3.5, 1.0], dtype=float)   # [SELL, FLAT, BUY]
weights = weights / weights.mean()
class_weights = torch.tensor(weights, dtype=torch.float32).to(device)

print('Class weights (SELL, FLAT, BUY):', class_weights.cpu().numpy().round(3))
print('Train distribution:\n',
      pd.Series(y_train).value_counts(normalize=True).sort_index()
        .rename({0: 'SELL', 1: 'FLAT', 2: 'BUY'}).mul(100).round(1))

optimizer = torch.optim.AdamW(model.parameters(), lr=BASE_LR, weight_decay=WEIGHT_DECAY)

# Key changes vs previous config:
# - pr_weight 24.0 → 10.0: was so dominant (~68× rec_weight) that "predict FLAT always" was optimal
# - rec_weight 0.35 → 5.0: gives collapsed minority class a meaningful recovery gradient
# - loss_penalty 8.0 → 1.0: was reinforcing "never predict trades"; still penalises SL hits
# - gamma 1.5 → 2.0: stronger focus on misclassified hard examples (minority classes)
# - profit_weight 0.75 → 0.0: disable differentiable profit signal
loss_params = {
    'alpha':           class_weights,
    'gamma':           2.5,    # was 2.0 — higher focal exponent punishes confident wrong calls harder
    'trade_classes':   (0, 2),
    'pr_weight':       10.0,   # was 10.0 — primary precision lever (~12:1 pr/rec ratio)
    'rec_weight':      4.0,    # was 2.0 — reduced but non-zero; keeps recall signal alive above 0.25
    'f1_weight':       2.0,
    'profit_weight':   0.0,    # Leaving at 0 for now until profit calculation is verified; can be increased to add direct profit signal from trade outcomes
    'loss_penalty':    2.0,    # was 3.5 — harder penalty on SL hits makes model more selective
    'direction_bonus': 0.40,   # was 0.3 — slightly stronger SELL-vs-BUY signal
    'eps':             1e-6,
}

criterion = TradeProfitabilityLoss(**loss_params)
# Out:
# Class weights (SELL, FLAT, BUY): [0.545 1.909 0.545]
# Train distribution:
#  SELL     2.0
# FLAT    95.7
# BUY      2.3
# Name: proportion, dtype: float64

# %% [markdown]
# ## Training Loop
#
# Runs for `NUM_EPOCHS` with **linear warmup + cosine decay** LR scheduling.
# Per-class metrics (F1, precision, recall) are plotted separately for SELL and BUY after each epoch.
#
# ### Experiment Notes
# _Record hyperparameter observations and results here._

# %%
from sklearn.metrics import (ConfusionMatrixDisplay, classification_report,
                             accuracy_score, confusion_matrix,
                             precision_recall_fscore_support)
from IPython.display import clear_output

use_amp = device.type == 'cuda'
torch.backends.cuda.matmul.allow_tf32 = True
scaler_amp = torch.amp.GradScaler('cuda', enabled=use_amp)

warmup_steps = 400
total_steps  = len(train_loader) * NUM_EPOCHS

def lr_lambda(step):
    if step < warmup_steps:
        return float(step) / float(max(1, warmup_steps))
    progress = float(step - warmup_steps) / float(max(1, total_steps - warmup_steps))
    return 0.5 * (1.0 + math.cos(math.pi * progress))

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

train_losses, val_losses_all = [], []
f1_sell,   prec_sell,   rec_sell   = [], [], []
f1_buy,    prec_buy,    rec_buy    = [], [], []
pnl = []

best_val_loss   = float('inf')
best_model_state = None
best_epoch       = -1

for epoch in range(NUM_EPOCHS):

    # --- Train ---
    model.train()
    train_loss = 0.0
    for xb, yb, outcome_b in tqdm(train_loader, desc=f"Epoch {epoch}"):
        xb, yb = xb.to(device), yb.to(device)
        outcome_b = outcome_b.to(device) if isinstance(outcome_b, torch.Tensor) else outcome_b
        optimizer.zero_grad(set_to_none=True)
        with torch.amp.autocast('cuda', enabled=use_amp):
            loss = criterion(model(xb), yb, outcome_b)
        scaler_amp.scale(loss).backward()
        scaler_amp.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler_amp.step(optimizer)
        scaler_amp.update()
        scheduler.step()
        train_loss += loss.item()
    train_losses.append(train_loss / len(train_loader))

    # --- Validate ---
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    all_preds, all_targets, all_outcomes = [], [], []
    with torch.no_grad():
        for xb, yb, outcome_b in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            outcome_b = outcome_b.to(device) if isinstance(outcome_b, torch.Tensor) else outcome_b
            with torch.amp.autocast('cuda', enabled=use_amp):
                logits   = model(xb)
                val_loss += criterion(logits, yb, outcome_b).item()
            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(yb.cpu().numpy())
            all_outcomes.extend(
                outcome_b.cpu().numpy() if isinstance(outcome_b, torch.Tensor) else outcome_b)
            correct += (preds == yb).sum().item()
            total   += yb.size(0)

    # --- Metrics ---
    all_preds_np    = np.array(all_preds)
    all_outcomes_np = np.array(all_outcomes)   # (N, 2)
    sell_mask = (all_preds_np == 0)
    buy_mask  = (all_preds_np == 2)

    # P&L: apply commission and sum over predicted trade bars
    sell_net    = all_outcomes_np[:, 0] - COMMISSION * np.abs(all_outcomes_np[:, 0])
    buy_net     = all_outcomes_np[:, 1] - COMMISSION * np.abs(all_outcomes_np[:, 1])
    profit_sell = float(sell_net[sell_mask].sum()) if sell_mask.any() else 0.0
    profit_buy  = float(buy_net[buy_mask].sum())   if buy_mask.any()  else 0.0
    profit      = profit_sell + profit_buy

    val_loss_value = val_loss / total
    acc = accuracy_score(all_targets, all_preds)

    # --- Checkpoint best model ---
    if val_loss_value < best_val_loss:
        best_val_loss    = val_loss_value
        best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        best_epoch       = epoch

    # Per-class precision/recall/F1 — average=None returns one value per class [SELL, FLAT, BUY]
    p_per, r_per, f_per, _ = precision_recall_fscore_support(
        all_targets, all_preds, labels=[0, 1, 2], average=None, zero_division=0)
    f1s, ps, rs = f_per[0], p_per[0], r_per[0]   # SELL (class 0)
    f1b, pb, rb = f_per[2], p_per[2], r_per[2]   # BUY  (class 2)

    val_losses_all.append(val_loss_value)
    f1_sell.append(f1s);  prec_sell.append(ps);  rec_sell.append(rs)
    f1_buy.append(f1b);   prec_buy.append(pb);   rec_buy.append(rb)
    pnl.append(profit)

    # --- Plot ---
    clear_output(wait=True)
    print(f"Epoch {epoch} | Acc: {acc:.4f} | "
          f"Profit (after {COMMISSION:.0%} commission): {profit:.0f} "
          f"[SELL: {profit_sell:.0f}  BUY: {profit_buy:.0f}] | "
          f"Val Loss: {val_loss_value:.6f}"
          f"{'  ← best' if epoch == best_epoch else f'  (best: {best_val_loss:.6f} @ epoch {best_epoch})'}\n")
    print(classification_report(all_targets, all_preds,
                                 target_names=['SELL', 'FLAT', 'BUY'], zero_division=0))

    fig, ax = plt.subplots(figsize=(6, 5))
    ConfusionMatrixDisplay(confusion_matrix(all_targets, all_preds),
                           display_labels=['SELL', 'FLAT', 'BUY']).plot(
        cmap='Blues', values_format='d', ax=ax)
    ax.set_title('Confusion Matrix (SELL / FLAT / BUY)')
    plt.show()

    fig, axes = plt.subplots(2, 2, figsize=(14, 8))

    axes[0, 0].plot(val_losses_all)
    axes[0, 0].axvline(best_epoch, color='red', linestyle='--', alpha=0.7, label=f'Best (epoch {best_epoch})')
    axes[0, 0].set_title('Val Loss')
    axes[0, 0].legend(fontsize=7)

    axes[0, 1].plot(f1_sell,  label='F1 SELL',   color='tab:blue')
    axes[0, 1].plot(f1_buy,   label='F1 BUY',    color='tab:green')
    axes[0, 1].plot(rec_sell, label='Rec SELL',  color='tab:blue',  linestyle='--', alpha=0.6)
    axes[0, 1].plot(rec_buy,  label='Rec BUY',   color='tab:green', linestyle='--', alpha=0.6)
    ax2 = axes[0, 1].twinx()
    ax2.plot(prec_sell, label='Prec SELL', color='tab:orange')
    ax2.plot(prec_buy,  label='Prec BUY',  color='tab:red')
    axes[0, 1].set_title('F1 & Recall (left axis) | Precision (right axis)')
    axes[0, 1].legend(loc='upper left', fontsize=7)
    ax2.legend(loc='upper right', fontsize=7)

    axes[1, 0].axis('off')

    axes[1, 1].plot(pnl, color='blue', linewidth=2, label='Total')
    axes[1, 1].axhline(0, color='black', linestyle='--', alpha=0.3)
    axes[1, 1].set_title(f'Val Profit after {COMMISSION:.0%} commission (SELL+BUY combined)')
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()

print(f"\nTraining complete. Best val loss: {best_val_loss:.6f} at epoch {best_epoch}")
# Out:
# Epoch 2 | Acc: 0.9295 | Profit (after 10% commission): 1548 [SELL: 269  BUY: 1279] | Val Loss: 0.040941  ← best
#
#               precision    recall  f1-score   support
#
#         SELL       0.21      0.06      0.09      8267
#         FLAT       0.96      0.97      0.97    298364
#          BUY       0.21      0.30      0.25      8478
#
#     accuracy                           0.93    315109
#    macro avg       0.46      0.44      0.44    315109
# weighted avg       0.92      0.93      0.93    315109
# Epoch 3:   8%|▊         | 869/11086 [01:11<14:04, 12.09it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 35
#      33 model.train()
#      34 train_loss = 0.0
# ---> 35 for xb, yb, outcome_b in tqdm(train_loader, desc=f"Epoch {epoch}"):
#      36     xb, yb = xb.to(device), yb.to(device)
#      37     outcome_b = outcome_b.to(device) if isinstance(outcome_b, torch.Tensor) else outcome_b
#
# File c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\torch\utils\data\dataloader.py:803, in _SingleProcessDataLoaderIter._next_data(self)
#     801 data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802 if self._pin_memory:
# --> 803     data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#     804 return data
#
# File c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\torch\utils\data\_utils\pin_memory.py:92, in pin_memory(data, device)
#      90     clone = copy.copy(data)  # type: ignore[arg-type]
#      91     for i, item in enumerate(data):
# ---> 92         clone[i] = pin_memory(item, device)
#      93     return clone
#      94 return type(data)([pin_memory(sample, device) for sample in data])  # type: ignore[call-arg]
#
# File c:\Users\Stuart\Desktop\Trading Bot\MLQ5-Production\.venv\Lib\site-packages\torch\utils\data\_utils\pin_memory.py:57, in pin_memory(data, device)
#      55 def pin_memory(data, device=None):
#      56     if isinstance(data, torch.Tensor):
# ---> 57         return data.pin_memory(device)
#      58     elif isinstance(data, (str, bytes)):
#      59         return data
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save Model Pack
#
# Saves the full model pack (weights, params, scaler, features, preprocessing functions)
# to `Engine/Model Packs/`.  A single multiclass pack replaces the paired BUY+SELL packs
# used by the binary workflow.

# %%
import pickle
import inspect

today      = pd.Timestamp.now().strftime('%Y%m%d')
ds_title   = DS_NAME.split('/')[-1].split('.')[0]
model_name = '_'.join([ds_title, MODEL_TYPE, str(SEQ_LEN) + 'seq', today, MODEL_VERSION])

model_info = {
    'dataset_name':  ds_title,
    'dataset_dir':   DS_NAME,
    'date_trained':  today,
    'model_type':    MODEL_TYPE,
    'task':          'multiclass',
    'class_map':     {0: 'SELL', 1: 'FLAT', 2: 'BUY'},
    'seq_len':       SEQ_LEN,
    'class_weights': weights.tolist(),
    'n_epochs':      NUM_EPOCHS,
}

loss_params_serializable = {**loss_params, 'alpha': loss_params['alpha'].cpu().tolist()}

with open(f'../Engine/Model Packs/{model_name}_model.pkl', 'wb') as f:
    pickle.dump({
        # ── Model ────────────────────────────────────────────────────────────
        'model':              model.state_dict(),
        'model_class':        TCNAttentionSEClassifier,
        'model_class_source': inspect.getsource(TCNAttentionSEClassifier),
        'model_params':       model_params,
        'model_info':         model_info,

        # ── Features & Preprocessing ─────────────────────────────────────────
        'features':                   features,
        'feature_count':              X_train.shape[1],
        'feature_function':           FEATURES,
        'feature_function_source':    inspect.getsource(FEATURES),
        'preprocess_function':        preprocess_ohlcv,
        'preprocess_function_source': inspect.getsource(preprocess_ohlcv),
        'preprocess_args':            preprocess_ohlcv_args,
        'scaler':                     scaler,

        # ── Labeling & Outcomes ──────────────────────────────────────────────
        'label_function':          causal_triple_barrier_hilow_trend_labeler,
        'label_function_source':   inspect.getsource(causal_triple_barrier_hilow_trend_labeler),
        'label_params':            label_params,
        'regime_params':           regime_params,
        'outcome_params':          outcome_params,
        'rollover_window':         ROLLOVER_WINDOW,
        'trading_hours':           TRADING_HOURS,

        # ── Training Config ──────────────────────────────────────────────────
        'input_shape':   (SEQ_LEN, X_train.shape[1]),
        'loss_params':   loss_params_serializable,
        'loss_function': TradeProfitabilityLoss,
        'loss_function_source': inspect.getsource(TradeProfitabilityLoss),
        'data_split': {
            'test_start_date': TEST_START,
            'train_rows':      len(X_train),
            'val_rows':        len(X_test),
            'holdout_size':    HOLDOUT_SIZE,
        },
        'torch_version': torch.__version__,

        # ── Validation Metrics ───────────────────────────────────────────────
        'val_metrics': {
            'final_f1_sell':        f1_sell[-1],   'final_f1_buy':        f1_buy[-1],
            'final_precision_sell': prec_sell[-1], 'final_precision_buy': prec_buy[-1],
            'final_recall_sell':    rec_sell[-1],  'final_recall_buy':    rec_buy[-1],
            'final_profit':         pnl[-1],
            'best_f1_sell':         max(f1_sell),  'best_f1_buy':         max(f1_buy),
            'best_precision_sell':  max(prec_sell),'best_precision_buy':  max(prec_buy),
            'f1_sell_curve':        f1_sell,        'f1_buy_curve':        f1_buy,
            'precision_sell_curve': prec_sell,      'precision_buy_curve': prec_buy,
            'recall_sell_curve':    rec_sell,        'recall_buy_curve':   rec_buy,
            'pnl_curve':            pnl,
        },
    }, f)

print('Saved', model_name + '_model')

# %%
'a' + 'b'
